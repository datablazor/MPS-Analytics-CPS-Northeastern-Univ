# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('KickstarterData.csv')
df.head()
# Out:
#    Donate ID Donate Date  Gender  Deposit Amount Preferred Color of Device  \
# 0          1    01-07-19  female           100.0                     white
# 1          2    01-07-19  female           100.0                      blue
# 2          3    01-07-19  female           100.0                    silver
# 3          4    01-07-19  female           100.0                    silver
# 4          5    01-07-19    male           100.0                     white
#
#    Ice Cream Products Consumed Per Week Favorite Flavor Of Ice Cream  \
# 0                                   4.0                      vanilla
# 1                                   5.0                      vanilla
# 2                                   6.0                      vanilla
# 3                                   5.0                      vanilla
# 4                                   1.0                      vanilla
#
#   Donated To Kick Starter Before Household Income Do you own a Keurig  \
# 0                            yes             <50K                 yes
# 1                            yes             <50K                 yes
# 2                            yes             <50K                 yes
# 3                            yes             <50K                 yes
# 4                            yes             <50K                 yes
#
#    How many desserts do you eat a week
# 0                                    7
# 1                                    5
# 2                                    1
# 3                                    4
# 4                                    7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
# Donate ID                               10000 non-null int64
# Donate Date                             10000 non-null object
# Gender                                  10000 non-null object
# Deposit Amount                          9960 non-null float64
# Preferred Color of Device               10000 non-null object
# Ice Cream Products Consumed Per Week    9896 non-null float64
# Favorite Flavor Of Ice Cream            10000 non-null object
# Donated To Kick Starter Before          10000 non-null object
# Household Income                        5199 non-null object
# Do you own a Keurig                     10000 non-null object
# How many desserts do you eat a week     10000 non-null int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 859.5+ KB

# %%
df.drop('Donate ID', axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Donate Date  Gender  Deposit Amount Preferred Color of Device  \
# 0    01-07-19  female           100.0                     white
# 1    01-07-19  female           100.0                      blue
# 2    01-07-19  female           100.0                    silver
# 3    01-07-19  female           100.0                    silver
# 4    01-07-19    male           100.0                     white
#
#    Ice Cream Products Consumed Per Week Favorite Flavor Of Ice Cream  \
# 0                                   4.0                      vanilla
# 1                                   5.0                      vanilla
# 2                                   6.0                      vanilla
# 3                                   5.0                      vanilla
# 4                                   1.0                      vanilla
#
#   Donated To Kick Starter Before Household Income Do you own a Keurig  \
# 0                            yes             <50K                 yes
# 1                            yes             <50K                 yes
# 2                            yes             <50K                 yes
# 3                            yes             <50K                 yes
# 4                            yes             <50K                 yes
#
#    How many desserts do you eat a week
# 0                                    7
# 1                                    5
# 2                                    1
# 3                                    4
# 4                                    7

# %%
df.isnull().sum()
# Out:
# Donate Date                                0
# Gender                                     0
# Deposit Amount                            40
# Preferred Color of Device                  0
# Ice Cream Products Consumed Per Week     104
# Favorite Flavor Of Ice Cream               0
# Donated To Kick Starter Before             0
# Household Income                        4801
# Do you own a Keurig                        0
# How many desserts do you eat a week        0
# dtype: int64

# %%
df.drop(['Household Income'], axis = 1)
# Out:
#      Donate Date  Gender  Deposit Amount Preferred Color of Device  \
# 0       01-07-19  female           100.0                     white
# 1       01-07-19  female           100.0                      blue
# 2       01-07-19  female           100.0                    silver
# 3       01-07-19  female           100.0                    silver
# 4       01-07-19    male           100.0                     white
# ...          ...     ...             ...                       ...
# 9995    09-07-19    male           100.0                     black
# 9996    09-07-19    male           100.0                    silver
# 9997    09-07-19    male             NaN                      blue
# 9998    09-07-19    male             NaN                      blue
# 9999    09-07-19    male             NaN                     black
#
#       Ice Cream Products Consumed Per Week Favorite Flavor Of Ice Cream  \
# 0                                      4.0                      vanilla
# 1                                      5.0                      vanilla
# 2                                      6.0                      vanilla
# 3                                      5.0                      vanilla
# 4                                      1.0                      vanilla
# ...                                    ...                          ...
# 9995                                   4.0                    chocolate
# 9996                                   6.0                no preference
# 9997                                   3.0                    chocolate
# 9998                                   6.0                      vanilla
# 9999                                   7.0                    chocolate
#
#      Donated To Kick Starter Before Do you own a Keurig  \
# 0                               yes                 yes
# 1                               yes                 yes
# 2                               yes                 yes
# 3                               yes                 yes
# 4                               yes                 yes
# ...                             ...                 ...
# 9995                             no                  no
# 9996                            yes                 yes
# 9997                            yes                 yes
# 9998                             no                  no
# 9999                            yes                 yes
#
#       How many desserts do you eat a week
# 0                                       7
# 1                                       5
# 2                                       1
# 3                                       4
# 4                                       7
# ...                                   ...
# 9995                                    5
# 9996                                    6
# 9997                                    5
# 9998                                    5
# 9999                                    4
#
# [10000 rows x 9 columns]

# %%
meanOfIceCreamProds = round(df['Ice Cream Products Consumed Per Week'].mean(), 2)
meanOfIceCreamProds
# Out:
# 4.97

# %%
df['Ice Cream Products Consumed Per Week'].fillna(meanOfIceCreamProds, inplace = True)

# %%
df['Ice Cream Products Consumed Per Week'].isnull().sum()
# Out:
# 0

# %%
modeOfDepositAmount = df['Deposit Amount'].mode()[0]
modeOfDepositAmount
# Out:
# 100.0

# %%
df['Deposit Amount'].fillna(modeOfDepositAmount, inplace = True)
df['Deposit Amount'].isnull().sum()
# Out:
# 0

# %%
list(set(df.dtypes.tolist()))
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Deposit Amount  Ice Cream Products Consumed Per Week  \
# 0           100.0                                   4.0
# 1           100.0                                   5.0
# 2           100.0                                   6.0
# 3           100.0                                   5.0
# 4           100.0                                   1.0
#
#    How many desserts do you eat a week
# 0                                    7
# 1                                    5
# 2                                    1
# 3                                    4
# 4                                    7

# %%
df_num.hist(figsize=(20, 20), bins=100, xlabelsize=12, ylabelsize=12)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\hp\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\hp\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# array([[<AxesSubplot:title={'center':'Deposit Amount'}>,
#         <AxesSubplot:title={'center':'How many desserts do you eat a week'}>],
#        [<AxesSubplot:title={'center':'Ice Cream Products Consumed Per Week'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.describe()
# Out:
#        Deposit Amount  Ice Cream Products Consumed Per Week  \
# count     10000.00000                          10000.000000
# mean        140.90570                              4.968888
# std         126.99502                              3.158740
# min         100.00000                              0.000000
# 25%         100.00000                              2.000000
# 50%         100.00000                              5.000000
# 75%         119.00000                              8.000000
# max       10000.00000                             10.000000
#
#        How many desserts do you eat a week
# count                         10000.000000
# mean                              5.060700
# std                               2.897008
# min                               0.000000
# 25%                               3.000000
# 50%                               5.000000
# 75%                               7.000000
# max                             100.000000

# %%
df.plot.scatter(x="Ice Cream Products Consumed Per Week",y="How many desserts do you eat a week")
plt.show()

# %%
df.plot.scatter(x="Ice Cream Products Consumed Per Week",y="Deposit Amount")
plt.show()

# %%
df.plot.scatter(x="How many desserts do you eat a week",y="Deposit Amount")
plt.show()

# %%
sns.pairplot(data = df, vars=['Deposit Amount','Ice Cream Products Consumed Per Week','How many desserts do you eat a week'])
plt.show()

# %%
df[['Deposit Amount','Ice Cream Products Consumed Per Week','How many desserts do you eat a week']].corr()
sns.heatmap(df[['Deposit Amount','Ice Cream Products Consumed Per Week','How many desserts do you eat a week']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
df.groupby('Donated To Kick Starter Before')['Deposit Amount'].mean()
# Out:
# Donated To Kick Starter Before
# no     111.647349
# yes    154.954559
# Name: Deposit Amount, dtype: float64

# %%
df.groupby('Donated To Kick Starter Before')['Deposit Amount'].median()
# Out:
# Donated To Kick Starter Before
# no     100.0
# yes    100.0
# Name: Deposit Amount, dtype: float64

# %%
sns.boxplot(df['Donated To Kick Starter Before'], df['Deposit Amount'])
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.groupby('Do you own a Keurig')['Deposit Amount'].mean()
# Out:
# Do you own a Keurig
# no     137.581009
# yes    141.667404
# Name: Deposit Amount, dtype: float64

# %%
df.groupby('Do you own a Keurig')['Deposit Amount'].median()
# Out:
# Do you own a Keurig
# no     100.0
# yes    100.0
# Name: Deposit Amount, dtype: float64

# %%
sns.boxplot(df['Do you own a Keurig'], df['Deposit Amount'])
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Donated_Before_Or_Not'] = np.where(df['Donated To Kick Starter Before']=='yes',1,0)
df['Donated_Before_Or_Not'].value_counts()
# Out:
# 1    6756
# 0    3244
# Name: Donated_Before_Or_Not, dtype: int64

# %%
df['Keurig_Or_Not'] = np.where(df['Do you own a Keurig']=='yes',1,0)
df['Keurig_Or_Not'].value_counts()
# Out:
# 1    8136
# 0    1864
# Name: Keurig_Or_Not, dtype: int64

# %%
df.groupby('Gender')['Donated_Before_Or_Not'].mean().plot.bar()
plt.show()

# %%
df.groupby('Gender')['Keurig_Or_Not'].mean().plot.bar()
plt.show()

# %%
result = pd.pivot_table(data=df, index='Gender', columns='Preferred Color of Device',values='Donated_Before_Or_Not')
print(result)

sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()
# Out:
# Preferred Color of Device     black      blue  no preference       red  \
# Gender
# female                     0.646277  0.682741       0.649057  0.647482
# male                       0.679860  0.698782       0.681024  0.682243
#
# Preferred Color of Device    silver     white
# Gender
# female                     0.681250  0.675033
# male                       0.672185  0.703704

# %%
result = pd.pivot_table(data=df, index='Gender', columns='Preferred Color of Device',values='Keurig_Or_Not')
print(result)

sns.heatmap(result, annot=True, cmap = 'Blues', center=0.117)
plt.show()
# Out:
# Preferred Color of Device    black      blue  no preference       red  \
# Gender
# female                     0.81250  0.815990       0.797484  0.805755
# male                       0.83702  0.810631       0.811409  0.793224
#
# Preferred Color of Device    silver     white
# Gender
# female                     0.788750  0.813738
# male                       0.833333  0.838384

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
filename = "KickstarterData.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=15000,
    max_cols_analyzed=15,
)
# Out:
# Shape of your Data Set: (10000, 11)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         This does not include the Target column(s)
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 3
# Time to run AutoViz (in seconds) = 7.185
#
#  ###################### VISUALIZATION Completed ########################

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
sns.boxplot(x=df['How many desserts do you eat a week'])
# Out:
# <AxesSubplot:xlabel='How many desserts do you eat a week'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Deposit Amount                          19.0
# Ice Cream Products Consumed Per Week     6.0
# How many desserts do you eat a week      4.0
# Donated_Before_Or_Not                    1.0
# Keurig_Or_Not                            0.0
# dtype: float64

# %%
import math
import numpy as np 
import pandas as pd
import xgboost
import sklearn

import matplotlib.pyplot as plt #Matplotlib for Viz
import seaborn as sns #Seaborn for Viz
from scipy import stats #Outlier Analysis & Removal
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler #Scaling variables
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier #RF, GB
from sklearn.metrics import f1_score, log_loss, confusion_matrix 
from sklearn.multioutput import MultiOutputClassifier
from sklearn.datasets import make_classification
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA 

from xgboost import XGBClassifier

# %%
# reading data files and storing them in a dataframe
df_train_features = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_features.csv')
df_test_features = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/test_features.csv')
df_train_target_nonscored = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_targets_nonscored.csv')
df_train_target_scored = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_targets_scored.csv')

# %%
selected = df_train_features['cp_type'] == 'trt_cp'
df_train_features = df_train_features[selected].drop('cp_type', 1)

df_train_features['cp_dose'] = df_train_features['cp_dose'] == 'D1'

selected_test = df_test_features['cp_type'] == 'trt_cp'

df_train_target_scored = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_targets_scored.csv')[selected]
df_test_features = df_test_features.drop('cp_type', 1)

df_test_features['cp_dose'] = df_test_features['cp_dose'] == 'D1'

# %%
np.sum(df_train_features.iloc[:, 1:].values, axis = 0)
# Out:
# array([1053840, 11196, 6094.410200000001, -1752.4431000000097,
#        3695.8482000000045, 1783.5998000000004, 1865.0048999999938,
#        -3146.9475000000184, 266.13059999999786, -4484.669000000035,
#        -5264.554200000021, 2288.761799999978, -2940.4546999999834,
#        4451.416700000054, 2363.5914000000166, 4686.6018,
#        -4191.924499999988, -407.70599999999865, 2274.205500000007,
#        -3858.5677999999875, 2154.5001000000034, -1626.1501000000053,
#        -3169.195000000006, -1642.8664999999964, 1585.1015999999888,
#        -2543.0508000000013, -2788.2387999999946, -1704.0827999999908,
#        -2977.251599999985, 3226.809599999973, -1907.22570000001,
#        -1599.3519000000083, -4772.47010000001, 8827.050600000015,
#        -4147.388099999996, 1088.6721000000073, -1563.7459999999926,
#        2937.1383, -4338.137600000014, -14569.792199999985,
#        12979.364900000013, 4004.547800000011, -4894.403700000058,
#        -3473.847200000014, -2442.9782999999798, 602.6104000000037,
#        -555.5320000000045, -3446.257400000015, 4732.698300000005,
#        1231.8142000000012, 4393.912099999991, -538.2126000000014,
#        -14696.86930000006, 976.4555000000012, -1050.977299999995,
#        3768.932200000022, 6014.083999999985, -5073.304900000003,
#        -3338.8167999999882, -141.6060000000001, -10812.583099999947,
#        -5137.309000000018, -6.259399999999912, -5596.017399999991,
#        -5122.227700000026, -8957.208599999962, -1057.689900000001,
#        7337.595499999992, 387.4878000000015, -11531.653100000036,
#        4343.559499999998, 8798.581300000002, -410.3246999999995,
#        -2876.470300000011, -10077.138899999965, -1335.5411999999958,
#        6503.6959000000115, -11533.009399999984, -640.1553999999946,
#        -1498.9248000000036, 101.75759999999981, -229.9577000000008,
#        -2526.6805999999983, 635.2680999999935, 4982.062300000011,
#        6277.272299999954, 5784.276400000007, 1084.8731000000043,
#        7834.019200000012, -2135.296600000001, 2266.3796999999972,
#        295.9615999999976, 4926.566399999983, 10185.101999999906,
#        1637.4953000000057, 2214.495100000009, -142.42799999999988,
#        4987.494300000041, -9917.781900000058, 4533.910100000023,
#        -6497.113200000032, -702.9733999999947, 14109.959599999982,
#        3047.4785999999795, 4818.809100000003, 1264.7663999999993,
#        1692.512599999987, 2733.6732999999927, 8256.522499999966,
#        29.168499999999792, -2724.033500000004, -1638.4044999999978,
#        -2703.7692000000065, 4161.082099999999, -3383.7734000000087,
#        -11972.475599999962, -1015.4005999999981, -822.4050000000058,
#        4051.1620000000044, -5.882500000000166, 2577.929500000002,
#        -680.0418000000025, -2388.0827000000013, -8709.958899999956,
#        1016.8002999999989, 9818.868300000038, 1516.7101999999982,
#        -2494.8427000000247, 4932.789299999973, 997.3486000000008,
#        -5955.905000000038, 260.8519999999991, 5377.950200000004,
#        9322.305200000019, 4963.168999999987, 1022.2383000000017,
#        -2886.6086999999875, 4661.754600000031, -862.4839000000006,
#        -1459.7975000000054, -2839.172799999992, 4104.553900000032,
#        3914.4137999999944, -2873.137000000018, 5145.434299999996,
#        6279.531099999995, 6697.876100000045, 8772.861999999988,
#        7334.985800000012, 8047.197800000005, 6785.02249999997,
#        690.4049000000045, -2184.144500000006, -4191.961299999994,
#        -8912.558699999954, -3146.8499999999817, 2009.6663999999964,
#        6440.558499999989, -4224.982699999979, 2171.671999999998,
#        11761.052100000006, 5250.852700000015, -2300.179899999995,
#        -1303.569400000003, 4680.635500000029, 8227.763700000034,
#        2727.8124000000034, -3387.90260000001, -1190.9015000000036,
#        -695.5563000000054, -263.7239999999994, 682.5336000000055,
#        7372.05790000003, 1854.3327000000036, -3455.5695999999984,
#        1517.3968999999963, 5164.9560999999685, -488.57680000000136,
#        -1636.066799999998, 5104.553099999998, -3124.7024,
#        -2213.729200000014, 5081.249800000003, 7782.654800000034,
#        5677.06789999997, -4805.942600000012, -844.0376999999958,
#        -10739.633600000067, -7031.55220000002, 882.0706999999996,
#        3361.8870000000134, -298.43969999999973, 2143.0749999999894,
#        5970.268699999951, 2964.694799999998, -358.0814000000012,
#        -5406.368200000005, -9001.574999999975, -6381.486700000026,
#        4820.579700000017, 4331.496299999982, -2857.8133000000084,
#        2306.259699999983, 8873.199300000026, -5266.157899999982,
#        -591.7965000000012, -4200.287900000004, 2765.789800000008,
#        -2899.8406999999843, 1197.4301000000048, 10291.084399999929,
#        3036.863800000012, 2057.4741999999956, -2009.021599999992,
#        -293.16009999999835, 4243.795999999998, -2668.645800000011,
#        6942.553099999977, 1647.1123999999859, -248.12909999999889,
#        -1344.2882000000122, 873.617299999994, 5985.281999999994,
#        736.0484000000038, 226.78579999999755, -4543.34250000001,
#        -154.46679999999944, 890.826499999989, 6005.042599999994,
#        -1848.6106999999893, -11122.535299999989, 4518.707499999977,
#        -99.91600000000157, -1008.4765999999969, 3811.1745999999966,
#        569.9486000000007, -5539.529199999969, 5717.890300000023,
#        1794.3556999999962, -953.6742999999966, -6213.631600000019,
#        -5829.918899999973, 948.4023000000019, -3759.3905999999893,
#        3017.1853000000083, 4624.552400000001, 5397.63560000003,
#        4301.255100000005, -753.9678999999996, -802.5590999999991,
#        8433.16439999998, 3902.730699999996, -9472.915500000008,
#        5487.367100000013, 1267.3961999999974, -7.947499999999808,
#        1881.453600000003, 3735.182400000033, -893.4697999999963,
#        -11422.291500000016, -944.6564999999961, 5871.306999999947,
#        624.4881000000013, 7528.423999999976, -1035.0523000000082,
#        1605.0733999999882, 3661.536800000019, -320.9341999999991,
#        6924.943500000042, -6045.763399999993, -1208.4304000000009,
#        -892.9685000000021, 7669.8232999999955, -6007.050600000014,
#        -3272.9575999999784, -2941.6796999999906, 603.7266999999999,
#        -2080.6314999999954, -8669.060000000063, -2653.2945999999974,
#        2552.2485999999967, 236.34179999999947, -196.40590000000174,
#        -936.8889999999968, -2673.303899999996, -1908.2730000000013,
#        -2023.4185000000164, -4671.452399999987, 4339.097299999972,
#        -1656.4300000000007, -287.2136000000011, 4719.34470000002,
#        3008.79899999999, -5125.283899999968, -38.081799999999944,
#        -2952.0607000000014, -4767.599400000011, 4572.529299999969,
#        1282.6555000000035, -2138.577700000003, -10203.614400000073,
#        -4280.516099999983, -3011.0580000000205, -3027.034100000013,
#        5605.587399999993, -995.5716000000006, -5962.9674000000305,
#        -991.2120999999948, -4167.699899999997, -3064.9221000000043,
#        5210.140100000015, -1752.1312999999973, 8453.430899999981,
#        351.7815999999991, -2284.9797999999896, 5924.615599999972,
#        -4510.754700000023, -3331.7040999999635, -3500.7798000000093,
#        5744.866999999972, 308.66419999999863, -308.67309999999867,
#        4050.466200000001, -3405.5100999999836, -2094.6344000000026,
#        -1184.4734999999955, -893.6613000000006, -3271.960200000011,
#        6392.090099999992, -5482.076600000009, 9911.233800000013,
#        -1996.6530999999961, 3323.096399999983, 1595.4839999999967,
#        -10354.963300000038, 2809.790500000013, 7173.146099999964,
#        4697.135300000002, 2279.889000000005, 4408.802299999998,
#        -1300.167600000004, -2769.8048999999855, 699.2396000000017,
#        -1427.5591000000047, -1659.2222000000045, 2309.547499999989,
#        7758.441200000019, 1612.4945000000012, 1879.0592999999953,
#        -1462.1928999999993, 2239.5481000000023, 9126.045999999924,
#        2304.2835000000073, -2311.682699999996, 2109.0088999999944,
#        -6080.885499999988, 4326.250500000009, 2327.5302999999994,
#        467.8060999999999, -3200.046100000017, 3645.811599999968,
#        4467.166400000003, -6671.7839000000295, 1967.1445000000078,
#        3862.39760000001, -874.9139999999912, -7028.674700000014,
#        5676.7567000000145, 2686.2411999999817, 4592.409800000004,
#        7634.4747999999845, -9154.260299999964, -14505.92830000008,
#        -2308.4081000000006, 1282.9051999999988, -1642.6928999999966,
#        7024.878199999969, -10196.365099999939, 1532.7521999999922,
#        5192.561400000012, -1231.7312999999954, -5142.962799999998,
#        5181.062200000002, 2195.1982000000035, -904.6740000000033,
#        -1463.1001000000128, -1656.9031000000032, -4873.027799999995,
#        6620.555899999965, 1036.970500000002, -2593.3415999999875,
#        2029.0457000000126, -1204.836499999991, 6186.629899999998,
#        12657.482899999868, 5158.00500000003, -777.8174999999951,
#        137.2739999999988, -3128.1511000000014, 742.8132999999973,
#        96.82880000000084, -4727.440700000006, -3925.7906999999836,
#        -4731.988500000028, 4888.998300000027, 3522.9167999999972,
#        -537.4838000000032, -2229.83290000002, -10077.403299999985,
#        -4685.48609999999, 1527.8756000000026, 5219.435399999973,
#        -6392.0893000000115, -9441.305299999927, -3252.393200000001,
#        8228.44579999995, -4399.157500000003, -74.34910000000052,
#        3034.3699999999994, 10825.320299999978, 6263.742400000013,
#        419.8202000000001, -839.7776999999994, -8267.369300000026,
#        3270.3879999999817, -4756.582000000039, 6106.188300000009,
#        6779.224599999997, 5513.290699999993, 5232.001100000008,
#        -3738.891500000004, -4772.417599999991, 6371.406699999975,
#        791.7395000000018, -2905.434699999987, -6721.077299999991,
#        -4559.33040000002, 1407.1222999999975, 3944.2349000000213,
#        5418.030600000019, -7293.290199999975, -9922.23779999997,
#        -4754.565599999992, 4268.086799999994, 1641.2689999999964,
#        6959.138000000032, -1545.6228999999983, -923.6343999999953,
#        -1556.0127000000139, 2380.2710000000075, 276.25039999999865,
#        -2715.3323000000005, -108.56100000000049, 2507.9337000000046,
#        5955.671099999992, -810.2646000000008, 1273.5383000000097,
#        1949.7960999999934, -369.5471999999981, 1990.9249000000063,
#        1880.677800000007, -1445.692600000006, 9609.314100000005,
#        3059.8754999999765, 3273.889100000023, 824.2227999999984,
#        -2447.041399999994, -597.0400000000038, 2027.865899999993,
#        3294.2398999999828, 6274.62680000001, 1812.1287000000098,
#        -5779.231100000012, 445.0934000000003, 973.6854999999989,
#        -2761.8285999999853, -3948.515099999989, -269.01310000000035,
#        -749.1686000000027, -11080.250200000013, 7494.600299999969,
#        -2989.2426999999902, 2348.930300000011, 1798.3559000000014,
#        -1848.5896000000039, -2289.677499999996, 7977.34559999999,
#        -2068.4739999999915, -6534.299000000034, -886.4513000000003,
#        3032.241200000014, -11934.629699999972, -4199.757199999986,
#        6450.291699999983, 1287.439700000013, 1179.2746000000056,
#        4319.475200000034, -4691.9379999999765, 4184.913899999994,
#        -2254.8365000000035, -3614.167999999999, -466.34630000000135,
#        6120.792700000054, -54.7361999999997, 1636.1729000000003,
#        -7051.413000000021, 3070.629099999997, 3649.962900000007,
#        3343.3000999999927, -88.17040000000033, -15042.67290000002,
#        -2913.498000000012, -2100.2751000000017, -1161.3330999999935,
#        7517.068300000035, -1276.1517999999965, 7655.168599999996,
#        644.3488000000003, -3429.1459000000295, 1732.7311999999977,
#        -65.03890000000051, 6032.451400000009, -2727.760900000003,
#        -2018.623099999988, -2760.24720000001, -2023.3270999999977,
#        -59.67470000000027, 322.97320000000127, -3425.151300000019,
#        5236.476800000013, 1537.0361000000057, 5916.637099999998,
#        -4064.6903999999936, 6612.875899999991, 943.9240000000016,
#        -790.1431000000043, -8310.431900000018, 2451.642399999999,
#        -1959.0113999999987, -2761.6997999999853, -2807.003000000002,
#        3336.8533999999936, -3424.4346000000182, 6232.752199999983,
#        -1307.2666999999901, -1492.1023999999982, 4157.427300000015,
#        -2741.6225000000118, 6069.515599999968, 1960.9108000000037,
#        2455.410100000003, 218.36280000000068, -811.6701999999991,
#        3380.9210999999927, -1175.3496999999993, -4125.720000000011,
#        -3049.2664999999924, -7259.440800000004, -3498.306399999998,
#        1778.2593999999985, -4124.483199999991, -3131.9403999999977,
#        -1992.7385000000004, -5684.802800000008, -2099.6398000000177,
#        -1106.9854, 472.1257999999983, -4086.1042999999945,
#        323.1728999999993, -4758.1992999999875, -11280.153899999983,
#        -8269.756999999989, 327.5680000000013, -7593.52320000002,
#        5263.435400000021, 1573.3864999999896, -6108.984300000006,
#        -109.01400000000012, 6477.5684000000165, -717.3468,
#        6463.750300000047, -2802.220300000006, 2867.937000000007,
#        -1804.9463999999962, 1944.3611000000028, 79.06909999999972,
#        1425.6634999999897, -6404.971800000006, -3124.55339999999,
#        -883.1519999999991, -4382.7952999999925, 214.3322999999998,
#        -4088.0639000000074, -1076.8868999999963, 5018.089900000009,
#        1788.8686999999934, 3617.625600000002, -6366.401199999984,
#        6488.235999999991, -5400.00720000004, -3496.8789000000165,
#        5954.413599999993, 4561.4790000000075, -2261.492800000009,
#        4795.35740000001, 3806.981600000013, -740.5547000000029,
#        -1199.9507999999971, 1043.1135999999956, 5381.619899999996,
#        7158.2829999999585, 2745.8628000000067, -4077.6961,
#        1475.0577999999932, -3113.8968999999915, 967.7660000000054,
#        -1620.8536999999976, -2807.365999999988, -2495.1390999999944,
#        -844.3088999999976, -6433.769300000049, 3290.2074000000057,
#        4959.334100000008, -2839.2323999999876, 614.5836000000031,
#        1541.7575, 3685.149300000012, 4516.41640000001, -1649.4723,
#        -73.36900000000013, 4848.004800000005, 5593.5693000000065,
#        -2514.0898999999863, 1382.635599999992, -7275.688099999953,
#        37.64389999999951, 2073.478499999994, 5530.264500000033,
#        2619.3149000000044, -3139.953799999997, -4153.136200000002,
#        -3544.824999999997, 711.4463999999972, -3377.7514000000256,
#        1405.093000000002, -1499.851000000006, -10368.305400000014,
#        5235.133300000033, 5229.5448000000015, 4316.191800000028,
#        3970.0481999999834, -86.21340000000023, 4962.868299999965,
#        -1619.6053000000063, -2994.5390999999977, -6131.808499999995,
#        5388.029899999989, 7593.386599999952, -762.6475000000061,
#        -1686.8565999999978, 2057.9812000000015, -2420.3348999999953,
#        -3530.5227000000104, -3509.8447999999835, 508.70530000000207,
#        6568.85799999996, -6697.268800000005, -5147.794200000016,
#        6599.435900000007, -1734.044699999999, -3347.127499999992,
#        -6286.669899999988, -2805.185300000003, 1834.0011999999986,
#        -12488.227500000088, -1855.2068999999933, -7017.393999999987,
#        -465.07210000000055, 2235.4099999999985, -4015.2084999999793,
#        -4689.685300000009, 2185.1120999999875, -4626.557200000007,
#        506.7434000000027, 3158.9626000000058, 3938.2009000000194,
#        -3215.593499999987, -2193.228100000001, -1453.751100000014,
#        17.1239999999994, 2126.808500000002, 6977.584, 1935.5300000000086,
#        -6625.478800000038, 4004.560600000008, 4033.0936000000074,
#        -1369.0851000000048, 3844.065599999989, 3045.271100000012,
#        2260.5974000000006, 291.70329999999893, 1938.3676999999925,
#        1432.3162000000013, -1497.2459999999915, -3079.03399999999,
#        -713.4523999999974, -5301.556099999974, -8798.505899999955,
#        -1359.1053999999906, 16344.419599999987, 4431.134699999984,
#        -1155.6395999999997, 3121.4916999999896, 2081.8513000000094,
#        8125.292500000011, 4438.377900000001, 4419.243200000014,
#        -3369.064499999994, -1026.8864999999985, -656.6683000000025,
#        1377.9080000000145, -5201.906000000029, 2028.998599999986,
#        7561.7845000000225, 851.3954999999996, 7375.262599999975,
#        5838.56259999997, 4538.227199999988, -4779.650500000026,
#        -1603.3452999999981, 3074.4839999999913, 6505.429699999966,
#        -1050.8341000000003, 11225.101300000082, 6015.595299999997,
#        -5863.143599999986, 1754.5878999999964, -1038.208700000002,
#        -1249.765399999998, 4391.536499999969, -1070.4500999999973,
#        -4798.710199999977, 2049.323099999992, 683.1827000000022,
#        -4931.523900000033, -6362.141600000028, 12931.262900000029,
#        6105.1433999999945, 2331.3542999999895, 1430.6906999999999,
#        4833.881699999988, -1115.4823000000067, 5979.25630000002,
#        483.02819999999946, 2611.6878999999944, 994.1792000000022,
#        2059.334999999998, -2563.637499999999, 206.15130000000113,
#        1090.1169000000039, 1876.9080000000079, -846.7546999999968,
#        -9726.661000000066, -8176.123899999992, 4898.743299999979,
#        152.47179999999952, 5366.3222000000005, 519.9421000000003,
#        -4932.081500000021, -1323.0375999999999, 3646.968600000003,
#        -2374.3182999999967, -5569.648499999999, 2890.791599999992,
#        -8696.208899999985, -11206.413900000012, -11895.131799999996,
#        -8994.124100000014, -12161.714100000037, -10933.031900000029,
#        -13958.891000000021, -6749.559499999949, -11065.621399999915,
#        -11005.23239999998, -12025.674300000039, -11733.465700000019,
#        -12267.597100000099, -13026.436100000026, -7673.779900000067,
#        -10903.86559999997, -8050.654500000029, -11848.688500000006,
#        -15170.3026, -8220.298500000006, -10981.011399999947,
#        -12125.42170000004, -9207.896999999984, -7250.569699999999,
#        -11020.454799999998, -10932.691699999972, -14631.139600000042,
#        -10792.194700000025, -12132.25200000003, -7256.898899999976,
#        -9538.671699999957, -10603.948300000005, -8088.676899999995,
#        -13465.65650000006, -11257.515999999976, -8394.272199999978,
#        -11686.621399999975, -5332.126700000017, -14600.224599999941,
#        -9546.204200000007, -11871.814699999963, -11531.816099999958,
#        -11638.574099999976, -11233.449100000027, -10798.389099999999,
#        -12394.98590000007, -9840.20820000002, -11394.827500000047,
#        -12611.848699999919, -9538.593500000015, -9625.843599999973,
#        -11467.05400000002, -11260.580399999973, -9087.774900000008,
#        -10425.709399999956, -12008.869099999984, -6976.713799999973,
#        -11294.138499999968, -7267.664000000017, -13170.67250000006,
#        -12799.863399999987, -8789.075000000046, -10339.002499999946,
#        -14675.125099999954, -9838.583400000047, -15074.216799999966,
#        -10931.515600000008, -12120.971800000038, -10186.118899999994,
#        -6928.964799999965, -13221.102599999836, -8842.186600000008,
#        -11034.630800000064, -12189.71529999991, -586.5504000000001,
#        -11510.743999999935, -6933.448199999988, -11069.283400000106,
#        -10182.163199999977, -11228.611999999997, -11521.45410000002,
#        -12408.117199999966, -12021.182899999943, -10817.668300000005,
#        -11585.988000000043, -10028.395599999956, -8432.360899999961,
#        -7074.095200000076, -7971.171400000004, -9613.139099999966,
#        -11477.07889999998, -11235.08120000005, -12246.810399999993,
#        -12421.229999999983, -12580.071399999997, -8788.552100000015,
#        -11328.139400000056, -9309.19740000002, -11733.916200000034,
#        -7672.140500000015], dtype=object)

# %%
X = df_train_features.iloc[:, 1:]
easy_cat = []
for category in df_train_target_scored.columns[1:]:
    tg = df_train_target_scored[category]
    total = tg.sum()
    if total > 100: 
        continue
    depth = int(total/2)+1
    score = 0
    for cr in ['gini', 'entropy']:
        tree = DecisionTreeClassifier(criterion = cr, max_depth = depth)
        tree.fit(X, tg)
        score = max(score, f1_score(tg, tree.predict(X)))
        print(f'best score for {category} (size - {total}) = {f1_score(tg, tree.predict(X))} on criterion {cr} with depth = {depth}')
        if score == 1:
            easy_cat.append((category, cr, tree.get_depth(),total))
            print()
            break
    print()
# Out:
# best score for 5-alpha_reductase_inhibitor (size - 17) = 0.7857142857142858 on criterion gini with depth = 9
# best score for 5-alpha_reductase_inhibitor (size - 17) = 1.0 on criterion entropy with depth = 9
#
#
# best score for 11-beta-hsd1_inhibitor (size - 18) = 0.7142857142857143 on criterion gini with depth = 10
# best score for 11-beta-hsd1_inhibitor (size - 18) = 0.4347826086956522 on criterion entropy with depth = 10
#
# best score for acat_inhibitor (size - 24) = 0.7027027027027027 on criterion gini with depth = 13
# best score for acat_inhibitor (size - 24) = 1.0 on criterion entropy with depth = 13
#
#
# best score for acetylcholinesterase_inhibitor (size - 73) = 0.8769230769230769 on criterion gini with depth = 37
# best score for acetylcholinesterase_inhibitor (size - 73) = 1.0 on criterion entropy with depth = 37
#
#
# best score for adenosine_receptor_agonist (size - 54) = 0.8979591836734693 on criterion gini with depth = 28
# best score for adenosine_receptor_agonist (size - 54) = 1.0 on criterion entropy with depth = 28
#
#
# best score for adenosine_receptor_antagonist (size - 96) = 0.9273743016759777 on criterion gini with depth = 49
# best score for adenosine_receptor_antagonist (size - 96) = 1.0 on criterion entropy with depth = 49
#
#
# best score for adenylyl_cyclase_activator (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for adenylyl_cyclase_activator (size - 12) = 1.0 on criterion entropy with depth = 7
#
#
# best score for akt_inhibitor (size - 66) = 1.0 on criterion gini with depth = 34
#
#
# best score for aldehyde_dehydrogenase_inhibitor (size - 7) = 0.7272727272727273 on criterion gini with depth = 4
# best score for aldehyde_dehydrogenase_inhibitor (size - 7) = 1.0 on criterion entropy with depth = 4
#
#
# best score for alk_inhibitor (size - 42) = 0.8 on criterion gini with depth = 22
# best score for alk_inhibitor (size - 42) = 1.0 on criterion entropy with depth = 22
#
#
# best score for ampk_activator (size - 12) = 0.8 on criterion gini with depth = 7
# best score for ampk_activator (size - 12) = 0.8571428571428571 on criterion entropy with depth = 7
#
# best score for analgesic (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for analgesic (size - 12) = 0.8571428571428571 on criterion entropy with depth = 7
#
# best score for androgen_receptor_agonist (size - 48) = 0.8292682926829268 on criterion gini with depth = 25
# best score for androgen_receptor_agonist (size - 48) = 1.0 on criterion entropy with depth = 25
#
#
# best score for androgen_receptor_antagonist (size - 89) = 0.8289473684210525 on criterion gini with depth = 45
# best score for androgen_receptor_antagonist (size - 89) = 1.0 on criterion entropy with depth = 45
#
#
# best score for anesthetic_-_local (size - 80) = 0.9189189189189189 on criterion gini with depth = 41
# best score for anesthetic_-_local (size - 80) = 1.0 on criterion entropy with depth = 41
#
#
# best score for angiogenesis_inhibitor (size - 36) = 0.7368421052631579 on criterion gini with depth = 19
# best score for angiogenesis_inhibitor (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for angiotensin_receptor_antagonist (size - 37) = 0.7868852459016393 on criterion gini with depth = 19
# best score for angiotensin_receptor_antagonist (size - 37) = 1.0 on criterion entropy with depth = 19
#
#
# best score for anti-inflammatory (size - 73) = 0.8503937007874016 on criterion gini with depth = 37
# best score for anti-inflammatory (size - 73) = 1.0 on criterion entropy with depth = 37
#
#
# best score for antiarrhythmic (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for antiarrhythmic (size - 6) = 0.2857142857142857 on criterion entropy with depth = 4
#
# best score for antibiotic (size - 43) = 0.7536231884057971 on criterion gini with depth = 22
# best score for antibiotic (size - 43) = 1.0 on criterion entropy with depth = 22
#
#
# best score for anticonvulsant (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for anticonvulsant (size - 12) = 0.0 on criterion entropy with depth = 7
#
# best score for antifungal (size - 13) = 0.631578947368421 on criterion gini with depth = 7
# best score for antifungal (size - 13) = 0.7000000000000001 on criterion entropy with depth = 7
#
# best score for antihistamine (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for antihistamine (size - 12) = 0.8571428571428571 on criterion entropy with depth = 7
#
# best score for antimalarial (size - 18) = 0.7586206896551725 on criterion gini with depth = 10
# best score for antimalarial (size - 18) = 0.8387096774193548 on criterion entropy with depth = 10
#
# best score for antioxidant (size - 73) = 1.0 on criterion gini with depth = 37
#
#
# best score for antiprotozoal (size - 36) = 0.8571428571428571 on criterion gini with depth = 19
# best score for antiprotozoal (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for antiviral (size - 23) = 0.6857142857142856 on criterion gini with depth = 12
# best score for antiviral (size - 23) = 1.0 on criterion entropy with depth = 12
#
#
# best score for apoptosis_stimulant (size - 49) = 0.8470588235294119 on criterion gini with depth = 25
# best score for apoptosis_stimulant (size - 49) = 1.0 on criterion entropy with depth = 25
#
#
# best score for aromatase_inhibitor (size - 47) = 0.9069767441860465 on criterion gini with depth = 24
# best score for aromatase_inhibitor (size - 47) = 1.0 on criterion entropy with depth = 24
#
#
# best score for atm_kinase_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for atm_kinase_inhibitor (size - 6) = 0.0 on criterion entropy with depth = 4
#
# best score for atp-sensitive_potassium_channel_antagonist (size - 1) = 0.0 on criterion gini with depth = 1
# best score for atp-sensitive_potassium_channel_antagonist (size - 1) = 0.0 on criterion entropy with depth = 1
#
# best score for atp_synthase_inhibitor (size - 12) = 1.0 on criterion gini with depth = 7
#
#
# best score for atpase_inhibitor (size - 97) = 1.0 on criterion gini with depth = 49
#
#
# best score for atr_kinase_inhibitor (size - 19) = 0.972972972972973 on criterion gini with depth = 10
# best score for atr_kinase_inhibitor (size - 19) = 1.0 on criterion entropy with depth = 10
#
#
# best score for aurora_kinase_inhibitor (size - 96) = 1.0 on criterion gini with depth = 49
#
#
# best score for autotaxin_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for autotaxin_inhibitor (size - 6) = 0.923076923076923 on criterion entropy with depth = 4
#
# best score for bacterial_30s_ribosomal_subunit_inhibitor (size - 60) = 0.7499999999999999 on criterion gini with depth = 31
# best score for bacterial_30s_ribosomal_subunit_inhibitor (size - 60) = 1.0 on criterion entropy with depth = 31
#
#
# best score for bacterial_50s_ribosomal_subunit_inhibitor (size - 80) = 1.0 on criterion gini with depth = 41
#
#
# best score for bacterial_antifolate (size - 36) = 0.7368421052631579 on criterion gini with depth = 19
# best score for bacterial_antifolate (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for bacterial_dna_gyrase_inhibitor (size - 89) = 0.9012345679012346 on criterion gini with depth = 45
# best score for bacterial_dna_gyrase_inhibitor (size - 89) = 1.0 on criterion entropy with depth = 45
#
#
# best score for bacterial_membrane_integrity_inhibitor (size - 7) = 0.6 on criterion gini with depth = 4
# best score for bacterial_membrane_integrity_inhibitor (size - 7) = 1.0 on criterion entropy with depth = 4
#
#
# best score for bcl_inhibitor (size - 31) = 0.6808510638297872 on criterion gini with depth = 16
# best score for bcl_inhibitor (size - 31) = 1.0 on criterion entropy with depth = 16
#
#
# best score for bcr-abl_inhibitor (size - 38) = 0.8656716417910448 on criterion gini with depth = 20
# best score for bcr-abl_inhibitor (size - 38) = 1.0 on criterion entropy with depth = 20
#
#
# best score for benzodiazepine_receptor_agonist (size - 67) = 0.8833333333333333 on criterion gini with depth = 34
# best score for benzodiazepine_receptor_agonist (size - 67) = 1.0 on criterion entropy with depth = 34
#
#
# best score for beta_amyloid_inhibitor (size - 24) = 0.7027027027027027 on criterion gini with depth = 13
# best score for beta_amyloid_inhibitor (size - 24) = 1.0 on criterion entropy with depth = 13
#
#
# best score for bromodomain_inhibitor (size - 68) = 1.0 on criterion gini with depth = 35
#
#
# best score for btk_inhibitor (size - 29) = 0.8163265306122449 on criterion gini with depth = 15
# best score for btk_inhibitor (size - 29) = 1.0 on criterion entropy with depth = 15
#
#
# best score for calcineurin_inhibitor (size - 6) = 0.8 on criterion gini with depth = 4
# best score for calcineurin_inhibitor (size - 6) = 0.0 on criterion entropy with depth = 4
#
# best score for cannabinoid_receptor_agonist (size - 42) = 0.962962962962963 on criterion gini with depth = 22
# best score for cannabinoid_receptor_agonist (size - 42) = 1.0 on criterion entropy with depth = 22
#
#
# best score for cannabinoid_receptor_antagonist (size - 55) = 0.8043478260869564 on criterion gini with depth = 28
# best score for cannabinoid_receptor_antagonist (size - 55) = 1.0 on criterion entropy with depth = 28
#
#
# best score for carbonic_anhydrase_inhibitor (size - 36) = 0.7368421052631579 on criterion gini with depth = 19
# best score for carbonic_anhydrase_inhibitor (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for casein_kinase_inhibitor (size - 36) = 0.8750000000000001 on criterion gini with depth = 19
# best score for casein_kinase_inhibitor (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for caspase_activator (size - 18) = 0.6666666666666666 on criterion gini with depth = 10
# best score for caspase_activator (size - 18) = 0.6153846153846153 on criterion entropy with depth = 10
#
# best score for catechol_o_methyltransferase_inhibitor (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for catechol_o_methyltransferase_inhibitor (size - 12) = 0.8695652173913043 on criterion entropy with depth = 7
#
# best score for cck_receptor_antagonist (size - 18) = 0.7586206896551725 on criterion gini with depth = 10
# best score for cck_receptor_antagonist (size - 18) = 1.0 on criterion entropy with depth = 10
#
#
# best score for chelating_agent (size - 54) = 0.8750000000000001 on criterion gini with depth = 28
# best score for chelating_agent (size - 54) = 1.0 on criterion entropy with depth = 28
#
#
# best score for chk_inhibitor (size - 24) = 1.0 on criterion gini with depth = 13
#
#
# best score for chloride_channel_blocker (size - 42) = 0.88 on criterion gini with depth = 22
# best score for chloride_channel_blocker (size - 42) = 1.0 on criterion entropy with depth = 22
#
#
# best score for cholesterol_inhibitor (size - 48) = 0.8837209302325582 on criterion gini with depth = 25
# best score for cholesterol_inhibitor (size - 48) = 1.0 on criterion entropy with depth = 25
#
#
# best score for cholinergic_receptor_antagonist (size - 54) = 0.7865168539325843 on criterion gini with depth = 28
# best score for cholinergic_receptor_antagonist (size - 54) = 1.0 on criterion entropy with depth = 28
#
#
# best score for coagulation_factor_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for coagulation_factor_inhibitor (size - 6) = 0.2857142857142857 on criterion entropy with depth = 4
#
# best score for corticosteroid_agonist (size - 36) = 1.0 on criterion gini with depth = 19
#
#
# best score for dihydrofolate_reductase_inhibitor (size - 36) = 0.8387096774193548 on criterion gini with depth = 19
# best score for dihydrofolate_reductase_inhibitor (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for dipeptidyl_peptidase_inhibitor (size - 25) = 0.6842105263157895 on criterion gini with depth = 13
# best score for dipeptidyl_peptidase_inhibitor (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for diuretic (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for diuretic (size - 6) = 0.0 on criterion entropy with depth = 4
#
# best score for dna_alkylating_agent (size - 48) = 0.9894736842105264 on criterion gini with depth = 25
# best score for dna_alkylating_agent (size - 48) = 1.0 on criterion entropy with depth = 25
#
#
# best score for elastase_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for elastase_inhibitor (size - 6) = 0.5 on criterion entropy with depth = 4
#
# best score for erbb2_inhibitor (size - 1) = 0.0 on criterion gini with depth = 1
# best score for erbb2_inhibitor (size - 1) = 0.0 on criterion entropy with depth = 1
#
# best score for estrogen_receptor_antagonist (size - 48) = 0.8292682926829268 on criterion gini with depth = 25
# best score for estrogen_receptor_antagonist (size - 48) = 1.0 on criterion entropy with depth = 25
#
#
# best score for faah_inhibitor (size - 36) = 0.8923076923076924 on criterion gini with depth = 19
# best score for faah_inhibitor (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for farnesyltransferase_inhibitor (size - 18) = 0.6666666666666666 on criterion gini with depth = 10
# best score for farnesyltransferase_inhibitor (size - 18) = 1.0 on criterion entropy with depth = 10
#
#
# best score for fatty_acid_receptor_agonist (size - 25) = 0.7499999999999999 on criterion gini with depth = 13
# best score for fatty_acid_receptor_agonist (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for fgfr_inhibitor (size - 50) = 1.0 on criterion gini with depth = 26
#
#
# best score for focal_adhesion_kinase_inhibitor (size - 18) = 0.7142857142857143 on criterion gini with depth = 10
# best score for focal_adhesion_kinase_inhibitor (size - 18) = 1.0 on criterion entropy with depth = 10
#
#
# best score for free_radical_scavenger (size - 18) = 0.6666666666666666 on criterion gini with depth = 10
# best score for free_radical_scavenger (size - 18) = 0.972972972972973 on criterion entropy with depth = 10
#
# best score for fungal_squalene_epoxidase_inhibitor (size - 23) = 0.7894736842105263 on criterion gini with depth = 12
# best score for fungal_squalene_epoxidase_inhibitor (size - 23) = 1.0 on criterion entropy with depth = 12
#
#
# best score for gamma_secretase_inhibitor (size - 56) = 1.0 on criterion gini with depth = 29
#
#
# best score for glutamate_inhibitor (size - 13) = 0.8181818181818181 on criterion gini with depth = 7
# best score for glutamate_inhibitor (size - 13) = 0.5555555555555556 on criterion entropy with depth = 7
#
# best score for glutamate_receptor_agonist (size - 74) = 0.8527131782945736 on criterion gini with depth = 38
# best score for glutamate_receptor_agonist (size - 74) = 1.0 on criterion entropy with depth = 38
#
#
# best score for gonadotropin_receptor_agonist (size - 18) = 0.7142857142857143 on criterion gini with depth = 10
# best score for gonadotropin_receptor_agonist (size - 18) = 1.0 on criterion entropy with depth = 10
#
#
# best score for gsk_inhibitor (size - 60) = 1.0 on criterion gini with depth = 31
#
#
# best score for hcv_inhibitor (size - 72) = 0.8923076923076924 on criterion gini with depth = 37
# best score for hcv_inhibitor (size - 72) = 1.0 on criterion entropy with depth = 37
#
#
# best score for histamine_receptor_agonist (size - 59) = 0.8200000000000001 on criterion gini with depth = 30
# best score for histamine_receptor_agonist (size - 59) = 1.0 on criterion entropy with depth = 30
#
#
# best score for histone_lysine_demethylase_inhibitor (size - 24) = 0.9565217391304348 on criterion gini with depth = 13
# best score for histone_lysine_demethylase_inhibitor (size - 24) = 1.0 on criterion entropy with depth = 13
#
#
# best score for histone_lysine_methyltransferase_inhibitor (size - 32) = 0.72 on criterion gini with depth = 17
# best score for histone_lysine_methyltransferase_inhibitor (size - 32) = 1.0 on criterion entropy with depth = 17
#
#
# best score for hiv_inhibitor (size - 72) = 0.8 on criterion gini with depth = 37
# best score for hiv_inhibitor (size - 72) = 1.0 on criterion entropy with depth = 37
#
#
# best score for hsp_inhibitor (size - 93) = 1.0 on criterion gini with depth = 47
#
#
# best score for igf-1_inhibitor (size - 37) = 1.0 on criterion gini with depth = 19
#
#
# best score for ikk_inhibitor (size - 30) = 0.9655172413793104 on criterion gini with depth = 16
# best score for ikk_inhibitor (size - 30) = 1.0 on criterion entropy with depth = 16
#
#
# best score for imidazoline_receptor_agonist (size - 31) = 0.6808510638297872 on criterion gini with depth = 16
# best score for imidazoline_receptor_agonist (size - 31) = 1.0 on criterion entropy with depth = 16
#
#
# best score for immunosuppressant (size - 73) = 1.0 on criterion gini with depth = 37
#
#
# best score for insulin_secretagogue (size - 30) = 0.7499999999999999 on criterion gini with depth = 16
# best score for insulin_secretagogue (size - 30) = 1.0 on criterion entropy with depth = 16
#
#
# best score for insulin_sensitizer (size - 51) = 0.9263157894736842 on criterion gini with depth = 26
# best score for insulin_sensitizer (size - 51) = 1.0 on criterion entropy with depth = 26
#
#
# best score for integrin_inhibitor (size - 42) = 0.88 on criterion gini with depth = 22
# best score for integrin_inhibitor (size - 42) = 1.0 on criterion entropy with depth = 22
#
#
# best score for jak_inhibitor (size - 92) = 1.0 on criterion gini with depth = 47
#
#
# best score for laxative (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for laxative (size - 6) = 0.6666666666666666 on criterion entropy with depth = 4
#
# best score for leukotriene_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for leukotriene_inhibitor (size - 6) = 0.2857142857142857 on criterion entropy with depth = 4
#
# best score for leukotriene_receptor_antagonist (size - 62) = 0.9122807017543859 on criterion gini with depth = 32
# best score for leukotriene_receptor_antagonist (size - 62) = 1.0 on criterion entropy with depth = 32
#
#
# best score for lipase_inhibitor (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for lipase_inhibitor (size - 12) = 1.0 on criterion entropy with depth = 7
#
#
# best score for lipoxygenase_inhibitor (size - 61) = 0.8039215686274509 on criterion gini with depth = 31
# best score for lipoxygenase_inhibitor (size - 61) = 1.0 on criterion entropy with depth = 31
#
#
# best score for lxr_agonist (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for lxr_agonist (size - 6) = 0.6666666666666666 on criterion entropy with depth = 4
#
# best score for mdm_inhibitor (size - 31) = 1.0 on criterion gini with depth = 16
#
#
# best score for mek_inhibitor (size - 72) = 1.0 on criterion gini with depth = 37
#
#
# best score for membrane_integrity_inhibitor (size - 74) = 0.9037037037037037 on criterion gini with depth = 38
# best score for membrane_integrity_inhibitor (size - 74) = 1.0 on criterion entropy with depth = 38
#
#
# best score for mineralocorticoid_receptor_antagonist (size - 25) = 0.6486486486486487 on criterion gini with depth = 13
# best score for mineralocorticoid_receptor_antagonist (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for monoacylglycerol_lipase_inhibitor (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for monoacylglycerol_lipase_inhibitor (size - 12) = 0.9090909090909091 on criterion entropy with depth = 7
#
# best score for monoamine_oxidase_inhibitor (size - 85) = 0.9940828402366864 on criterion gini with depth = 43
# best score for monoamine_oxidase_inhibitor (size - 85) = 1.0 on criterion entropy with depth = 43
#
#
# best score for monopolar_spindle_1_kinase_inhibitor (size - 18) = 0.7586206896551725 on criterion gini with depth = 10
# best score for monopolar_spindle_1_kinase_inhibitor (size - 18) = 0.8750000000000001 on criterion entropy with depth = 10
#
# best score for mucolytic_agent (size - 48) = 0.8705882352941177 on criterion gini with depth = 25
# best score for mucolytic_agent (size - 48) = 1.0 on criterion entropy with depth = 25
#
#
# best score for neuropeptide_receptor_antagonist (size - 37) = 0.7666666666666667 on criterion gini with depth = 19
# best score for neuropeptide_receptor_antagonist (size - 37) = 1.0 on criterion entropy with depth = 19
#
#
# best score for nicotinic_receptor_agonist (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for nicotinic_receptor_agonist (size - 6) = 0.2857142857142857 on criterion entropy with depth = 4
#
# best score for nitric_oxide_donor (size - 26) = 0.7727272727272727 on criterion gini with depth = 14
# best score for nitric_oxide_donor (size - 26) = 0.9803921568627451 on criterion entropy with depth = 14
#
# best score for nitric_oxide_production_inhibitor (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for nitric_oxide_production_inhibitor (size - 12) = 1.0 on criterion entropy with depth = 7
#
#
# best score for nitric_oxide_synthase_inhibitor (size - 26) = 0.7000000000000001 on criterion gini with depth = 14
# best score for nitric_oxide_synthase_inhibitor (size - 26) = 1.0 on criterion entropy with depth = 14
#
#
# best score for norepinephrine_reuptake_inhibitor (size - 7) = 0.6 on criterion gini with depth = 4
# best score for norepinephrine_reuptake_inhibitor (size - 7) = 0.25 on criterion entropy with depth = 4
#
# best score for nrf2_activator (size - 18) = 0.8387096774193548 on criterion gini with depth = 10
# best score for nrf2_activator (size - 18) = 1.0 on criterion entropy with depth = 10
#
#
# best score for opioid_receptor_agonist (size - 61) = 0.8598130841121495 on criterion gini with depth = 31
# best score for opioid_receptor_agonist (size - 61) = 1.0 on criterion entropy with depth = 31
#
#
# best score for opioid_receptor_antagonist (size - 96) = 0.9222222222222222 on criterion gini with depth = 49
# best score for opioid_receptor_antagonist (size - 96) = 1.0 on criterion entropy with depth = 49
#
#
# best score for orexin_receptor_antagonist (size - 37) = 0.8437499999999999 on criterion gini with depth = 19
# best score for orexin_receptor_antagonist (size - 37) = 1.0 on criterion entropy with depth = 19
#
#
# best score for p38_mapk_inhibitor (size - 62) = 1.0 on criterion gini with depth = 32
#
#
# best score for p-glycoprotein_inhibitor (size - 24) = 0.8292682926829268 on criterion gini with depth = 13
# best score for p-glycoprotein_inhibitor (size - 24) = 1.0 on criterion entropy with depth = 13
#
#
# best score for parp_inhibitor (size - 61) = 1.0 on criterion gini with depth = 31
#
#
# best score for pdk_inhibitor (size - 18) = 0.7142857142857143 on criterion gini with depth = 10
# best score for pdk_inhibitor (size - 18) = 1.0 on criterion entropy with depth = 10
#
#
# best score for phospholipase_inhibitor (size - 25) = 0.6842105263157895 on criterion gini with depth = 13
# best score for phospholipase_inhibitor (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for pkc_inhibitor (size - 31) = 0.76 on criterion gini with depth = 16
# best score for pkc_inhibitor (size - 31) = 1.0 on criterion entropy with depth = 16
#
#
# best score for potassium_channel_activator (size - 55) = 0.9320388349514563 on criterion gini with depth = 28
# best score for potassium_channel_activator (size - 55) = 1.0 on criterion entropy with depth = 28
#
#
# best score for potassium_channel_antagonist (size - 98) = 1.0 on criterion gini with depth = 50
#
#
# best score for ppar_receptor_antagonist (size - 30) = 0.6666666666666666 on criterion gini with depth = 16
# best score for ppar_receptor_antagonist (size - 30) = 1.0 on criterion entropy with depth = 16
#
#
# best score for progesterone_receptor_antagonist (size - 18) = 0.7586206896551725 on criterion gini with depth = 10
# best score for progesterone_receptor_antagonist (size - 18) = 1.0 on criterion entropy with depth = 10
#
#
# best score for prostaglandin_inhibitor (size - 36) = 0.6909090909090909 on criterion gini with depth = 19
# best score for prostaglandin_inhibitor (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for prostanoid_receptor_antagonist (size - 84) = 0.7737226277372262 on criterion gini with depth = 43
# best score for prostanoid_receptor_antagonist (size - 84) = 1.0 on criterion entropy with depth = 43
#
#
# best score for protein_kinase_inhibitor (size - 48) = 0.7692307692307693 on criterion gini with depth = 25
# best score for protein_kinase_inhibitor (size - 48) = 1.0 on criterion entropy with depth = 25
#
#
# best score for protein_phosphatase_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for protein_phosphatase_inhibitor (size - 6) = 0.2857142857142857 on criterion entropy with depth = 4
#
# best score for protein_tyrosine_kinase_inhibitor (size - 19) = 0.6428571428571429 on criterion gini with depth = 10
# best score for protein_tyrosine_kinase_inhibitor (size - 19) = 1.0 on criterion entropy with depth = 10
#
#
# best score for radiopaque_medium (size - 56) = 0.88 on criterion gini with depth = 29
# best score for radiopaque_medium (size - 56) = 1.0 on criterion entropy with depth = 29
#
#
# best score for ras_gtpase_inhibitor (size - 12) = 0.6666666666666666 on criterion gini with depth = 7
# best score for ras_gtpase_inhibitor (size - 12) = 0.8 on criterion entropy with depth = 7
#
# best score for retinoid_receptor_agonist (size - 67) = 1.0 on criterion gini with depth = 34
#
#
# best score for retinoid_receptor_antagonist (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for retinoid_receptor_antagonist (size - 6) = 0.0 on criterion entropy with depth = 4
#
# best score for rho_associated_kinase_inhibitor (size - 35) = 0.7499999999999999 on criterion gini with depth = 18
# best score for rho_associated_kinase_inhibitor (size - 35) = 1.0 on criterion entropy with depth = 18
#
#
# best score for ribonucleoside_reductase_inhibitor (size - 37) = 0.9577464788732395 on criterion gini with depth = 19
# best score for ribonucleoside_reductase_inhibitor (size - 37) = 1.0 on criterion entropy with depth = 19
#
#
# best score for rna_polymerase_inhibitor (size - 25) = 0.6486486486486487 on criterion gini with depth = 13
# best score for rna_polymerase_inhibitor (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for serotonin_reuptake_inhibitor (size - 44) = 0.7945205479452054 on criterion gini with depth = 23
# best score for serotonin_reuptake_inhibitor (size - 44) = 1.0 on criterion entropy with depth = 23
#
#
# best score for sigma_receptor_agonist (size - 36) = 0.6909090909090909 on criterion gini with depth = 19
# best score for sigma_receptor_agonist (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for sigma_receptor_antagonist (size - 36) = 0.7142857142857143 on criterion gini with depth = 19
# best score for sigma_receptor_antagonist (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for smoothened_receptor_antagonist (size - 25) = 0.7499999999999999 on criterion gini with depth = 13
# best score for smoothened_receptor_antagonist (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for sphingosine_receptor_agonist (size - 25) = 0.717948717948718 on criterion gini with depth = 13
# best score for sphingosine_receptor_agonist (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for src_inhibitor (size - 71) = 0.8818897637795275 on criterion gini with depth = 36
# best score for src_inhibitor (size - 71) = 1.0 on criterion entropy with depth = 36
#
#
# best score for steroid (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for steroid (size - 6) = 0.8 on criterion entropy with depth = 4
#
# best score for syk_inhibitor (size - 19) = 0.7333333333333334 on criterion gini with depth = 10
# best score for syk_inhibitor (size - 19) = 1.0 on criterion entropy with depth = 10
#
#
# best score for tachykinin_antagonist (size - 60) = 0.9915966386554621 on criterion gini with depth = 31
# best score for tachykinin_antagonist (size - 60) = 1.0 on criterion entropy with depth = 31
#
#
# best score for tgf-beta_receptor_inhibitor (size - 30) = 1.0 on criterion gini with depth = 16
#
#
# best score for thrombin_inhibitor (size - 19) = 0.6896551724137931 on criterion gini with depth = 10
# best score for thrombin_inhibitor (size - 19) = 0.6428571428571429 on criterion entropy with depth = 10
#
# best score for thymidylate_synthase_inhibitor (size - 37) = 0.7868852459016393 on criterion gini with depth = 19
# best score for thymidylate_synthase_inhibitor (size - 37) = 1.0 on criterion entropy with depth = 19
#
#
# best score for tlr_agonist (size - 30) = 0.8235294117647058 on criterion gini with depth = 16
# best score for tlr_agonist (size - 30) = 1.0 on criterion entropy with depth = 16
#
#
# best score for tlr_antagonist (size - 7) = 0.6 on criterion gini with depth = 4
# best score for tlr_antagonist (size - 7) = 0.0 on criterion entropy with depth = 4
#
# best score for tnf_inhibitor (size - 36) = 0.8387096774193548 on criterion gini with depth = 19
# best score for tnf_inhibitor (size - 36) = 1.0 on criterion entropy with depth = 19
#
#
# best score for transient_receptor_potential_channel_antagonist (size - 18) = 0.7586206896551725 on criterion gini with depth = 10
# best score for transient_receptor_potential_channel_antagonist (size - 18) = 0.6153846153846153 on criterion entropy with depth = 10
#
# best score for tropomyosin_receptor_kinase_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for tropomyosin_receptor_kinase_inhibitor (size - 6) = 0.6666666666666666 on criterion entropy with depth = 4
#
# best score for trpv_agonist (size - 25) = 0.888888888888889 on criterion gini with depth = 13
# best score for trpv_agonist (size - 25) = 1.0 on criterion entropy with depth = 13
#
#
# best score for trpv_antagonist (size - 48) = 0.9213483146067416 on criterion gini with depth = 25
# best score for trpv_antagonist (size - 48) = 1.0 on criterion entropy with depth = 25
#
#
# best score for tyrosine_kinase_inhibitor (size - 73) = 0.8682170542635659 on criterion gini with depth = 37
# best score for tyrosine_kinase_inhibitor (size - 73) = 1.0 on criterion entropy with depth = 37
#
#
# best score for ubiquitin_specific_protease_inhibitor (size - 6) = 0.6666666666666666 on criterion gini with depth = 4
# best score for ubiquitin_specific_protease_inhibitor (size - 6) = 0.0 on criterion entropy with depth = 4
#
# best score for vitamin_b (size - 26) = 0.7317073170731707 on criterion gini with depth = 14
# best score for vitamin_b (size - 26) = 1.0 on criterion entropy with depth = 14
#
#
# best score for vitamin_d_receptor_agonist (size - 39) = 1.0 on criterion gini with depth = 20
#
#
# best score for wnt_inhibitor (size - 30) = 0.7234042553191489 on criterion gini with depth = 16
# best score for wnt_inhibitor (size - 30) = 1.0 on criterion entropy with depth = 16

# %%
ct = [c[0] for c in easy_cat]
cr = [c[1] for c in easy_cat]
d = [c[2] for c in easy_cat]
s = [c[3] for c in easy_cat]

easy = pd.DataFrame({
    'categories': ct,
    'positive samples in dataset': s,
    'criterion is': cr,
    'with depth': d
})


easy.to_csv('light_categories.csv', index = False)

easy.sort_values(['positive samples in dataset', 'with depth'])
# Out:
#                                 categories  positive samples in dataset  \
# 7         aldehyde_dehydrogenase_inhibitor                            7
# 29  bacterial_membrane_integrity_inhibitor                            7
# 21                  atp_synthase_inhibitor                           12
# 5               adenylyl_cyclase_activator                           12
# 85       nitric_oxide_production_inhibitor                           12
# ..                                     ...                          ...
# 4            adenosine_receptor_antagonist                           96
# 89              opioid_receptor_antagonist                           96
# 24                 aurora_kinase_inhibitor                           96
# 22                        atpase_inhibitor                           97
# 98            potassium_channel_antagonist                           98
#
#    criterion is  with depth
# 7       entropy           4
# 29      entropy           4
# 21         gini           4
# 5       entropy           6
# 85      entropy           6
# ..          ...         ...
# 4       entropy          15
# 89      entropy          21
# 24         gini          27
# 22         gini          48
# 98         gini          46
#
# [128 rows x 4 columns]

# %%
sub = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/sample_submission.csv')
sub = sub.loc[:, pd.Index(easy['categories'])]

for cat, cr, depth in zip(easy['categories'], easy['criterion is'], easy['with depth']):
    tg = df_train_target_scored[category]
    tree = DecisionTreeClassifier(criterion = cr, max_depth = depth)
    tree.fit(X, tg)
    sub[cat] = tree.predict(df_test_features.iloc[:, 1:])

sub[~selected_test] = 0
sub.to_csv('tree_columns_results.csv', index = False)

# %%
# Random Forest

encode_values = {"cp_type": {"trt_cp": 0, "ctl_vehicle": 1},
                 "cp_time": {24: 0, 48: 1, 72: 2},
                 "cp_dose": {"D1": 0, "D2": 1}}

df_train_features.replace(encode_values, inplace=True)
df_test_features.replace(encode_values, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-a0f2205a30ca> in <module>
#       5                  "cp_dose": {"D1": 0, "D2": 1}}
#       6
# ----> 7 df_train_features.replace(encode_values, inplace=True)
#       8 df_test_features.replace(encode_values, inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4377         method="pad",
#    4378     ):
# -> 4379         return super().replace(
#    4380             to_replace=to_replace,
#    4381             value=value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6498                 to_replace, value = keys, values
#    6499
# -> 6500             return self.replace(
#    6501                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6502             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4377         method="pad",
#    4378     ):
# -> 4379         return super().replace(
#    4380             to_replace=to_replace,
#    4381             value=value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6516                         if col in value.keys() and col in self
#    6517                     }
# -> 6518                     return self._replace_columnwise(mapping, inplace, regex)
#    6519
#    6520                 # {'A': NA} -> 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _replace_columnwise(self, mapping, inplace, regex)
#    4413
#    4414                 target, value = mapping[ax[i]]
# -> 4415                 newobj = ser.replace(target, value, regex=regex)
#    4416
#    4417                 res.iloc[:, i] = newobj
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4561         method="pad",
#    4562     ):
# -> 4563         return super().replace(
#    4564             to_replace=to_replace,
#    4565             value=value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6541                         )
#    6542                     self._consolidate_inplace()
# -> 6543                     new_data = self._mgr.replace_list(
#    6544                         src_list=to_replace,
#    6545                         dest_list=value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in comp(s, mask, regex)
#     634
#     635             s = com.maybe_box_datetimelike(s)
# --> 636             return _compare_or_regex_search(values, s, regex, mask)
#     637
#     638         # Calculate the mask once, prior to the call of comp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _compare_or_regex_search(a, b, regex, mask)
#    1990     if is_datetimelike_v_numeric(a, b) or is_numeric_v_string_like(a, b):
#    1991         # GH#29553 avoid deprecation warnings from numpy
# -> 1992         _check_comparison_types(False, a, b)
#    1993         return False
#    1994
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _check_comparison_types(result, a, b)
#    1969                 type_names[0] = f"ndarray(dtype={a.dtype})"
#    1970
# -> 1971             raise TypeError(
#    1972                 f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1973             )
#
# TypeError: Cannot compare types 'ndarray(dtype=bool)' and 'str'

# %%
X_train = df_train_features.iloc[:,1:].to_numpy()
X_test = df_test_features.iloc[:,1:].to_numpy()
y_train = df_train_target_scored.iloc[:,1:].to_numpy()
y_test = df_test_features.iloc[:,1:].to_numpy()

# %%
model = RandomForestClassifier(n_estimators=200,max_depth=10, random_state=
                               0,min_samples_split=10)
model.fit(X_train,y_train)

# %%
#Generating predictions from Random Forest Models
feature_list=df_train_features.columns

pred_rf=model.predict(X_test)
pred_rf_proba=model.predict_proba(X_test)

feat_importances = pd.Series(model.feature_importances_, index=feature_list[1:])
feat_importances=feat_importances.sort_values()
feat_importances.plot(kind='barh',figsize=(16,16))#Plotting feature importance

# %%
import xgboost
from xgboost import XGBClassifier
from sklearn.multioutput import MultiOutputClassifier

xgb = MultiOutputClassifier(XGBClassifier(tree_method='gpu_hist'))

params = {'estimator__colsample_bytree': 0.6522,
          'estimator__gamma': 3.6975,
          'estimator__learning_rate': 0.0503,
          'estimator__max_delta_step': 2.0706,
          'estimator__max_depth': 10,
          'estimator__min_child_weight': 31.5800,
          'estimator__n_estimators': 166,
          'estimator__subsample': 0.8639
         }

xgb.set_params(**params)
xgb.fit(X_train,y_train)

# %%
pred_xg_proba = xgb.predict_proba(X_test)
print(pred_xg_proba)

# %%
grad_boost_classifier = GradientBoostingClassifier(learning_rate=0.01,max_depth=2,random_state=0)
    #title = 'Gradient boosting binary dataset'
   # plot_class_regions_for_classifier_subplot(grad_boost_classifier,X_train,y_train,X_test,y_test,title)
grad_boost_classifier.fit(X_train,y_train)

predicted_values = grad_boost_classifier.predict(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder, QuantileTransformer
from sklearn.model_selection import KFold
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.multioutput import MultiOutputClassifier

# %%
from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import callbacks
import keras
from sklearn.metrics import log_loss
from keras.regularizers import L1, L2

# %%
drug = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_features.csv')
target = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_targets_scored.csv')

# setting the sig_id column as index
drug.set_index('sig_id', inplace= True)
target.set_index('sig_id', inplace= True)

treat_drug = drug.query('cp_type == "trt_cp"')
treat_target = target.loc[treat_drug.index]

# %%
# Getting list of columns names for categorical features, numerical features, gene epxression related features and cell vialbility related features
cat_cols = drug.select_dtypes(include = 'O').columns.tolist()
num_cols = drug.select_dtypes(exclude = 'O').columns.tolist()
gene_features = [i for i in num_cols if i.startswith('g-')]
cell_viability = [i for i in num_cols if i.startswith('c-')]
cat_cols2 = cat_cols + ['cp_time']
num_cols2 = num_cols
num_cols.remove('cp_time')

# %%
# Data prepocesing i.e label encoding 'cp_dose', 'cp_time' and 'cp_type', or whether to drop vehicle/control treated sample rows

qt = QuantileTransformer()

def data_preprocessing(dataframe, only_treatment = True, fit = False, transform = False):
    df = dataframe.copy()
    if fit:
        df[num_cols] = qt.fit_transform(df[num_cols])
    if transform:
        df[num_cols] = qt.transform(df[num_cols])
    df["cp_dose"] = df.cp_dose.map({"D1": 0, "D2":1})
    df["cp_time"] = df.cp_time.map({24: 0,48: 1, 72: 2})
    if only_treatment:
        df = df.drop("cp_type", 1)
    else:
        df["cp_type"] = df.cp_type.map({"trt_cp": 1, "ctl_vehicle":0})
    return df


drug_cleaned = data_preprocessing(dataframe= drug, only_treatment= False, fit= True, transform= False)
drug_treatment = data_preprocessing(dataframe= drug, only_treatment= True,fit= True, transform= False)

# %%
# Defining NN model to be optimized using Optuna hyperparameter optimization:

def for_bayes_optimization2(dimension):
    
    [dl1,dl2,dl3,dl4,dp1,dp2,dp3,dp4,regu,regu_val,activation,learning_rate] = dimension
    if (regu == 'l2'):
        act_reg = keras.regularizers.l2(regu_val)
    if (regu =='l1'):
        act_reg = keras.regularizers.l1(regu_val)
    lr = callbacks.ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 5, verbose = 0)
    
    #x_train,x_val, y_train, y_val = train_test_split(drug_cleaned, target, test_size = 0.3, random_state = 42)
    es = callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 1e-4, mode = 'min', baseline = 0.3 , 
                                 restore_best_weights=False, patience= 30, verbose = 0)
    
    adam = keras.optimizers.Adam(learning_rate = learning_rate)
    
    model = Sequential()
    model.add(Dense(dl1, input_dim = x_train.shape[1], activation = activation, activity_regularizer = act_reg))
    model.add(Dropout(dp1))
    model.add(Dense(dl2, activation = activation))
    model.add(Dropout(dp2))
    model.add(Dense(dl3, activation = activation))
    model.add(Dropout(dp3))
    model.add(Dense(dl4, activation = activation))
    model.add(Dropout(dp4))
    model.add(Dense(y_train.shape[1], activation = 'sigmoid'))
    
    model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['AUC'])
    
    model.fit(x = x_train, y = y_train, validation_data = (x_val, y_val), epochs = 200, batch_size = 128, callbacks = [es], verbose = 0)
    
    log_loss_data = log_loss(np.ravel(y_val), np.ravel(model.predict_proba(x_val)), eps = 1e-7) 
    
    return model # or return log_loss_data (for optuna optimization)

# %%
# Best parameters obtained from Optuna 
best_set_from_baysian_optimization = [2048, 1982, 708, 470, 0.6067766671093088, 0.1, 0.4973213653064633, 0.5950996340056243, 'l1', 1e-05, 'swish', 0.0001]

# %%
#Prepartion of sample submission file
submission_test = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/test_features.csv')
submission_test_prob = pd.read_csv('/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/sample_submission.csv')
submission_test_cleaned = data_preprocessing(dataframe= submission_test, only_treatment= False, fit= False, transform= True)
submission_test_prob.set_index('sig_id', inplace= True)
submission_test_cleaned.set_index('sig_id', inplace = True)
submission_test_cleaned

# %%
#setting initial prediction for all to zeros
submission_test_prob[:] = np.zeros(submission_test_prob.shape)
submission_test_prob

# %%
# For submission_File_prediction
n_splits = 5
sub_file = submission_test_cleaned
sub_file_all_predict = np.zeros(submission_test_prob.shape)
nn_loss = [] # neural network loss
xgb_loss = [] # xgb loss
combined_loss = [] # loss of ensembel of NN and XGB
for seed in [10, 20, 30]: # trying three dfiferent seeds

    for e, (train, val) in enumerate(KFold(n_splits = n_splits, shuffle = True, random_state = seed).split(drug_cleaned, target)):
        x_train, y_train = drug_cleaned.iloc[train], target.iloc[train]
        x_val, y_val = drug_cleaned.iloc[val], target.iloc[val]

        model = for_bayes_optimization2(best_set_from_baysian_optimization)
        
        nn_predict = model.predict_proba(x_val)
        
        sub_file_nn_predict = model.predict_proba(sub_file)
        nn_loss_temp = log_loss(np.ravel(y_val), np.ravel(nn_predict), eps = 1e-7)
        nn_loss.append(nn_loss_temp)
        print(f"NN_log_loss fold {e}, seed {seed}: ", nn_loss_temp)
        
        xgb = MultiOutputClassifier(XGBClassifier(tree_method = 'gpu_hist', n_estimators = 130, max_depth = 3, reg_alpha = 2, min_child_weight = 2,
                                             gamma = 3, learning_rate = 0.0580666601841646, colsample_bytree = 0.58)) # Parameters obtained after optimization with Optuna
        xgb.fit(x_train, y_train)
        xgb_predict = np.array(xgb.predict_proba(x_val))[:,:,1].T
        xgb_loss_temp = log_loss(np.ravel(y_val), np.ravel(xgb_predict), eps = 1e-7)
        xgb_loss.append(xgb_loss_temp)
        
        sub_file_xgb_predict = np.array(xgb.predict_proba(sub_file))[:,:,1].T
        avg_sub_file_predict = (sub_file_nn_predict + sub_file_xgb_predict)/2
        
        sub_file_all_predict = sub_file_all_predict + avg_sub_file_predict
        
        combined_loss_temp  = log_loss(np.ravel(y_val), np.ravel((nn_predict + xgb_predict)/2), eps = 1e-7)
        combined_loss.append(combined_loss_temp)
        
        print(f"xgb_log_loss fold {e}, seed {seed}: ", xgb_loss_temp)
        print(f"combined_loss fold {e}, seed {seed}: ", combined_loss_temp)

# %%
print("Average log loss of NN is :", np.mean(nn_loss), " and standard deviation: ", np.std(nn_loss))
print("Average log loss of Xgboost is :", np.mean(xgb_loss), " and standard deviation: ", np.std(xgb_loss))
print("Combined log loss is :", np.mean(combined_loss), " and standard deviation: ", np.std(combined_loss))

# %%
final_predictions = sub_file_all_predict/(n_splits * 3)

# %%
submission_test_prob[:] = final_predictions

# %%
submission_test_prob = np.clip(submission_test_prob, 0.0005, 0.99)
submission_test_prob.iloc[submission_test.query('cp_type == "ctl_vehicle"').index] = 0.0

# %%
submission_test_prob.to_csv('submission.csv')

# %%
import pandas as pd
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
SEED = 255

moa_df     = pd.read_csv("/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_features.csv", index_col = 0)
moa_labels = pd.read_csv("/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/train_targets_scored.csv", index_col = 0)

moa_df['cp_type'] = moa_df['cp_type'].map({"trt_cp" : 1, "ctl_vehicle" : 0})
moa_df['cp_time'] = moa_df['cp_time'].map({24 : 0, 48 : 0.5, 72 : 1})
moa_df['cp_dose'] = moa_df['cp_dose'].map({'D1' : 0, 'D2' : 1})

scaler = MinMaxScaler()
moa_df.iloc[:,3:] = scaler.fit_transform(moa_df.iloc[:,3:])
    
X = moa_df.values
y = moa_labels.values

PARAMS = {
    "n_estimators": 767,
    "gamma": 1,
    "alpha": 0.5723441911553176,
    "lambda": 2,
    "max_depth": 8,
    "subsample": 0.8072479047241428,
    "learning_rate": 0.009879006755753497,
    "min_child_weight": 7,
    "max_delta_step": 10
}

clf = OneVsRestClassifier(XGBClassifier(tree_method = 'gpu_hist', 
                                        gpu_id = 0,
                                        objective = "binary:logistic",
                                        random_state = SEED,
                                        **PARAMS))


clf.fit(X,y)

test   = pd.read_csv("/Users/dhirenpagarani/Northeastern University/Fundamentals of Artificial Intelligence - EAI6000/lish-moa/test_features.csv", index_col = 0)

test['cp_type'] = test['cp_type'].map({"trt_cp" : 1, "ctl_vehicle" : 0})
test['cp_time'] = test['cp_time'].map({24 : 0, 48 : 0.5, 72 : 1})
test['cp_dose'] = test['cp_dose'].map({'D1' : 0, 'D2' : 1})
test.iloc[:,3:] = scaler.transform(test.iloc[:,3:])
    
X_test = test.values

y_pred = clf.predict_proba(X_test)

submission = pd.DataFrame(y_pred, index = test.index, columns = moa_labels.columns)
submission.head()

submission.to_csv("submission.csv")
